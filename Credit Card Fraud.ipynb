# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
cd=pd.read_csv('D://Atos//creditcard.csv')

# %%
cd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
# Time      284807 non-null float64
# V1        284807 non-null float64
# V2        284807 non-null float64
# V3        284807 non-null float64
# V4        284807 non-null float64
# V5        284807 non-null float64
# V6        284807 non-null float64
# V7        284807 non-null float64
# V8        284807 non-null float64
# V9        284807 non-null float64
# V10       284807 non-null float64
# V11       284807 non-null float64
# V12       284807 non-null float64
# V13       284807 non-null float64
# V14       284807 non-null float64
# V15       284807 non-null float64
# V16       284807 non-null float64
# V17       284807 non-null float64
# V18       284807 non-null float64
# V19       284807 non-null float64
# V20       284807 non-null float64
# V21       284807 non-null float64
# V22       284807 non-null float64
# V23       284807 non-null float64
# ...

# %%
cd.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# ...

# %%
print('Fraud transaction',round(cd['Class'].value_counts()[1]/len(cd)*100,2),'%')
print('Genuine transaction',round(cd['Class'].value_counts()[0]/len(cd)*100,2),'%')
# Out:
# Fraud transaction 0.17 %
# Genuine transaction 99.83 %

# %%
# visualizing the class imbalance
sns.countplot('Class',data=cd)

# %%
#analysing non anonymized features
cd.hist('Amount') #data is heavily right skewewd
cd.hist('Time')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000278DEAF7550>]],
#       dtype=object)

# %%
#checkiing co=relation 
corr=cd.corr()
corr
# Out:
#             Time            V1            V2            V3            V4  \
# Time    1.000000  1.173963e-01 -1.059333e-02 -4.196182e-01 -1.052602e-01
# V1      0.117396  1.000000e+00  4.697350e-17 -1.424390e-15  1.755316e-17
# V2     -0.010593  4.697350e-17  1.000000e+00  2.512175e-16 -1.126388e-16
# V3     -0.419618 -1.424390e-15  2.512175e-16  1.000000e+00 -3.416910e-16
# V4     -0.105260  1.755316e-17 -1.126388e-16 -3.416910e-16  1.000000e+00
# V5      0.173072  6.391162e-17 -2.039868e-16 -1.436514e-15 -1.940929e-15
# V6     -0.063016  2.398071e-16  5.024680e-16  1.431581e-15 -2.712659e-16
# V7      0.084714  1.991550e-15  3.966486e-16  2.168574e-15  1.556330e-16
# V8     -0.036949 -9.490675e-17 -4.413984e-17  3.433113e-16  5.195643e-16
# V9     -0.008660  2.169581e-16 -5.728718e-17 -4.233770e-16  3.859585e-16
# V10     0.030617  7.433820e-17 -4.782388e-16  6.289267e-16  6.055490e-16
# V11    -0.247689  2.438580e-16  9.468995e-16 -5.501758e-17 -2.083600e-16
# ...

# %%
plt.figure(figsize=(12,10))
heat = sns.heatmap(data=corr)
plt.title('Heatmap of Correlation')
# Out:
# Text(0.5,1,'Heatmap of Correlation')

# %%
cd.skew()
# Out:
# Time      -0.035568
# V1        -3.280667
# V2        -4.624866
# V3        -2.240155
# V4         0.676292
# V5        -2.425901
# V6         1.826581
# V7         2.553907
# V8        -8.521944
# V9         0.554680
# V10        1.187141
# V11        0.356506
# V12       -2.278401
# V13        0.065233
# V14       -1.995176
# V15       -0.308423
# V16       -1.100966
# V17       -3.844914
# V18       -0.259880
# V19        0.109192
# V20       -2.037155
# V21        3.592991
# V22       -0.213258
# V23       -5.875140
# V24       -0.552499
# V25       -0.415793
# V26        0.576693
# V27       -1.170209
# V28       11.192091
# Amount    16.977724
# Class     23.997579
# dtype: float64

# %%
#scale Amount and Time
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler2 = StandardScaler()
#scaling time
scaled_time = scaler.fit_transform(cd[['Time']])
flat_list1 = [item for sublist in scaled_time.tolist() for item in sublist]
scaled_time = pd.Series(flat_list1)
#scaling the amount column
scaled_amount = scaler2.fit_transform(cd[['Amount']])
flat_list2 = [item for sublist in scaled_amount.tolist() for item in sublist]
scaled_amount = pd.Series(flat_list2)

# %%
cd['scaled_time']=scaled_time
cd['scaled_amount']=scaled_amount
cd.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9      ...             V23       V24       V25       V26  \
# 0  0.098698  0.363787      ...       -0.110474  0.066928  0.128539 -0.189115
# 1  0.085102 -0.255425      ...        0.101288 -0.339846  0.167170  0.125895
# 2  0.247676 -1.514654      ...        0.909412 -0.689281 -0.327642 -0.139097
# 3  0.377436 -1.387024      ...       -0.190321 -1.175575  0.647376 -0.221929
# 4 -0.270533  0.817739      ...       -0.137458  0.141267 -0.206010  0.502292
#
# ...

# %%
cd.drop(['Amount', 'Time'], axis=1, inplace=True)

# %%
X=cd.drop('Class',axis=1)
y=cd['Class']
from sklearn.decomposition import PCA
X_reduced_pca = PCA(n_components=2, random_state=42).fit_transform(X.values)

# %%
#before initiating sampling techniques we need to split the data
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.model_selection import KFold, StratifiedKFold

shuffle_split = StratifiedKFold(n_splits=5, random_state=None, shuffle=False)
for train_index, test_index in shuffle_split.split(X_reduced_pca, y):
    print("Train:", train_index, "Test:", test_index)
    original_Xtrain, original_Xtest = X_reduced_pca[train_index], X_reduced_pca[test_index]
    original_ytrain, original_ytest = y.iloc[train_index], y.iloc[test_index]

original_Xtrain = original_Xtrain
original_Xtest = original_Xtest
original_ytrain = original_ytrain.values
original_ytest = original_ytest.values
# Out:
# Train: [ 30473  30496  31002 ... 284804 284805 284806] Test: [    0     1     2 ... 57017 57018 57019]
# Train: [     0      1      2 ... 284804 284805 284806] Test: [ 30473  30496  31002 ... 113964 113965 113966]
# Train: [     0      1      2 ... 284804 284805 284806] Test: [ 81609  82400  83053 ... 170946 170947 170948]
# Train: [     0      1      2 ... 284804 284805 284806] Test: [150654 150660 150661 ... 227866 227867 227868]
# Train: [     0      1      2 ... 227866 227867 227868] Test: [212516 212644 213092 ... 284804 284805 284806]

# %%
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_reduced_pca, y, test_size=0.3, random_state=0)

print("Number transactions X_train dataset: ", X_train.shape)
print("Number transactions y_train dataset: ", y_train.shape)
print("Number transactions X_test dataset: ", X_test.shape)
print("Number transactions y_test dataset: ", y_test.shape)
# Out:
# Number transactions X_train dataset:  (199364, 2)
# Number transactions y_train dataset:  (199364,)
# Number transactions X_test dataset:  (85443, 2)
# Number transactions y_test dataset:  (85443,)

# %%
print("Before OverSampling, counts of label '1': {}".format(sum(y_train==1)))
print("Before OverSampling, counts of label '0': {} \n".format(sum(y_train==0)))

sm = SMOTE(random_state=2)
X_train_res, y_train_res = sm.fit_sample(X_train, y_train.ravel())

print('After OverSampling, the shape of train_X: {}'.format(X_train_res.shape))
print('After OverSampling, the shape of train_y: {} \n'.format(y_train_res.shape))

print("After OverSampling, counts of label '1': {}".format(sum(y_train_res==1)))
print("After OverSampling, counts of label '0': {}".format(sum(y_train_res==0)))
# Out:
# Before OverSampling, counts of label '1': 345
# Before OverSampling, counts of label '0': 199019
#
# After OverSampling, the shape of train_X: (398038, 2)
# After OverSampling, the shape of train_y: (398038,)
#
# After OverSampling, counts of label '1': 199019
# After OverSampling, counts of label '0': 199019

# %%
#creating a dummy model to achieve accuracy
from sklearn.dummy import DummyClassifier
clf = DummyClassifier().fit(X_train_res,y_train_res)
y_pred = clf.predict(X_test)
#Distribution of y test
print('y actual : \n' +  str(y_test.value_counts()))

#Distribution of y predicted
print('y predicted : \n' + str(pd.Series(y_pred).value_counts()))
# Out:
# y actual :
# 0    85296
# 1      147
# Name: Class, dtype: int64
# y predicted :
# 1    42722
# 0    42721
# dtype: int64

# %%
#Evaluation metrics for the dummy model

from sklearn.metrics import accuracy_score,recall_score,precision_score,f1_score
print('Accuracy Score : ' + str(accuracy_score(y_test,y_pred)))
print('Precision Score : ' + str(precision_score(y_test,y_pred)))
print('Recall Score : ' + str(recall_score(y_test,y_pred)))
print('F1 Score : ' + str(f1_score(y_test,y_pred)))

#Dummy Classifier Confusion matrix
from sklearn.metrics import confusion_matrix
print('Confusion Matrix : \n' + str(confusion_matrix(y_test,y_pred)))
# Out:
# Accuracy Score : 0.49986540734758844
# Precision Score : 0.0015916857825008192
# Recall Score : 0.46258503401360546
# F1 Score : 0.0031724556206116305
# Confusion Matrix :
# [[42642 42654]
#  [   79    68]]

# %%
#applying logistic regression for the model

#Logistic regression
from sklearn.linear_model import LogisticRegression

clf = LogisticRegression().fit(X_train_res,y_train_res)
y_pred = clf.predict(X_test)

# Model Evaluation metrics 
from sklearn.metrics import accuracy_score,recall_score,precision_score,f1_score
print('Accuracy Score : ' + str(accuracy_score(y_test,y_pred)))
print('Precision Score : ' + str(precision_score(y_test,y_pred)))
print('Recall Score : ' + str(recall_score(y_test,y_pred)))
print('F1 Score : ' + str(f1_score(y_test,y_pred)))

#Logistic Regression Classifier Confusion matrix
from sklearn.metrics import confusion_matrix
print('Confusion Matrix : \n' + str(confusion_matrix(y_test,y_pred)))
# Out:
# C:\Users\Aishwarya\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Accuracy Score : 0.7913111665086666
# Precision Score : 0.005867888677769085
# Recall Score : 0.7142857142857143
# F1 Score : 0.0116401529848678
# Confusion Matrix :
# [[67507 17789]
#  [   42   105]]

# %%
#Testing the logistic model with original data

clf = LogisticRegression(C=4,penalty='l1', verbose=5).fit(X_train_res,y_train_res)
y_pred = clf.predict(original_Xtest)

# Model Evaluation metrics 
from sklearn.metrics import accuracy_score,recall_score,precision_score,f1_score
print('Accuracy Score : ' + str(accuracy_score(original_ytest,y_pred)))
print('Precision Score : ' + str(precision_score(original_ytest,y_pred)))
print('Recall Score : ' + str(recall_score(original_ytest,y_pred)))
print('F1 Score : ' + str(f1_score(original_ytest,y_pred)))

#Logistic Regression Classifier Confusion matrix
from sklearn.metrics import confusion_matrix
print('Confusion Matrix : \n' + str(confusion_matrix(original_ytest,y_pred)))
# Out:
# C:\Users\Aishwarya\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# [LibLinear]Accuracy Score : 0.8589912396200909
# Precision Score : 0.006469270962926101
# Recall Score : 0.5306122448979592
# F1 Score : 0.0127826941986234
# Confusion Matrix :
# [[48877  7986]
#  [   46    52]]

# %%
y_score = clf.fit(X_train_res,y_train_res).decision_function(original_Xtest)
y_score
# Out:
# C:\Users\Aishwarya\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# [LibLinear]
# array([ 0.09278397, -0.11743854,  0.44974652, ..., -1.78247171,
#        -0.46077233, -0.6272481 ])

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
# calculate AUC
plt.title('Receiver Operating Characteristic')
auc = roc_auc_score(original_ytest,y_pred)
print('AUC: %.3f' % auc)
# calculate roc curve
fpr, tpr, thresholds = roc_curve(original_ytest,y_pred)
# plot no skill
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
# show the plot
plt.show()
# Out:
# AUC: 0.695

# %%
# check with decision tree
from sklearn import tree
dec_clf = tree.DecisionTreeClassifier().fit(X_train_res,y_train_res)
y_pred_dec = dec_clf.predict(X_test)
print('Accuracy Score : ' + str(accuracy_score(y_test,y_pred_dec)))
print('Precision Score : ' + str(precision_score(y_test,y_pred_dec)))
print('Recall Score : ' + str(recall_score(y_test,y_pred_dec)))
print('F1 Score : ' + str(f1_score(y_test,y_pred_dec)))

#Logistic Regression Classifier Confusion matrix
from sklearn.metrics import confusion_matrix
print('Confusion Matrix : \n' + str(confusion_matrix(y_test,y_pred_dec)))
# Out:
# Accuracy Score : 0.9318610067530401
# Precision Score : 0.010184705679268082
# Recall Score : 0.4013605442176871
# F1 Score : 0.01986531986531986
# Confusion Matrix :
# [[79562  5734]
#  [   88    59]]

# %%
# check with decision tree
from sklearn import tree
dec_clf = tree.DecisionTreeClassifier().fit(X_train_res,y_train_res)
y_pred_dec = dec_clf.predict(original_Xtest)

print('Accuracy Score : ' + str(accuracy_score(original_ytest,y_pred_dec)))
print('Precision Score : ' + str(precision_score(original_ytest,y_pred_dec)))
print('Recall Score : ' + str(recall_score(original_ytest,y_pred_dec)))
print('F1 Score : ' + str(f1_score(original_ytest,y_pred_dec)))

#Logistic Regression Classifier Confusion matrix
from sklearn.metrics import confusion_matrix
print('Confusion Matrix : \n' + str(confusion_matrix(original_ytest,y_pred_dec)))
# Out:
# Accuracy Score : 0.9820052316497252
# Precision Score : 0.0728110599078341
# Recall Score : 0.8061224489795918
# F1 Score : 0.13355874894336434
# Confusion Matrix :
# [[55857  1006]
#  [   19    79]]

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
# calculate AUC
plt.title('Receiver Operating Characteristic')
auc = roc_auc_score(original_ytest,y_pred_dec)
print('AUC: %.3f' % auc)
# calculate roc curve
fpr, tpr, thresholds = roc_curve(original_ytest,y_pred_dec)
# plot no skill
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
# show the plot
plt.show()
# Out:
# AUC: 0.894

# %%
#model evaluation
from sklearn import tree
classifiers = {
    "LogisiticRegression": LogisticRegression(),
    "DecisionTreeClassifier":tree.DecisionTreeClassifier()
}
from sklearn.model_selection import cross_val_score


for key, classifier in classifiers.items():
    classifier.fit(X_train, y_train)
    training_score = cross_val_score(classifier, X_train, y_train, cv=5)
    print("Classifiers: ", classifier.__class__.__name__, "Has a training score of", round(training_score.mean(), 2) * 100, "% accuracy score")
# Out:
# C:\Users\Aishwarya\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Aishwarya\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Aishwarya\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Aishwarya\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ...

# %%
#since I sense overfit I'll check cross validation scores of the models with regularization
from sklearn.model_selection import GridSearchCV
# Logistic Regression 
log_reg_params = {"penalty": ['l1', 'l2'], 'C': [0.001, 0.01, 0.1, 1, 10, 100, 1000]}
grid_log_reg = GridSearchCV(LogisticRegression(), log_reg_params)
grid_log_reg.fit( X_train_res,y_train_res)
# We automatically get the logistic regression with the best parameters.
log_reg = grid_log_reg.best_estimator_
# DecisionTree Classifier
tree_params = {"criterion": ["gini", "entropy"], "max_depth": list(range(2,4,1)), 
              "min_samples_leaf": list(range(5,7,1))}
grid_tree = GridSearchCV(tree.DecisionTreeClassifier(), tree_params)
grid_tree.fit( X_train_res,y_train_res)

# tree best estimator
tree_clf = grid_tree.best_estimator_
# Out:
# C:\Users\Aishwarya\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# C:\Users\Aishwarya\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Aishwarya\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Aishwarya\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ...

# %%
#Overfitting case
#Logistic regression
log_reg_score = cross_val_score(log_reg, X_train_res,y_train_res, cv=5)
print('Logistic Regression Cross Validation Score: ', round(log_reg_score.mean() * 100, 2).astype(str) + '%')
#Logistic Regression
tree_score = cross_val_score(tree_clf, X_train_res,y_train_res, cv=5)
print('DecisionTree Classifier Cross Validation Score', round(tree_score.mean() * 100, 2).astype(str) + '%')
# Out:
# C:\Users\Aishwarya\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Aishwarya\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Aishwarya\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Aishwarya\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ...

# %% [raw]
# from sklearn.model_selection import ShuffleSplit
# from sklearn.model_selection import learning_curve
#
# def plot_learning_curve(estimator, title, X, y, ylim=None, cv=None,n_jobs=None, train_sizes=np.linspace(.1, 1.0, 5)):
#     plt.figure()
#     plt.title(title)
#     if ylim is not None:
#         plt.ylim(*ylim)
#     plt.xlabel("Training examples")
#     plt.ylabel("Score")
#     train_sizes, train_scores, test_scores = learning_curve(
#         estimator, X,y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes)
#     train_scores_mean = np.mean(train_scores, axis=1)
#     train_scores_std = np.std(train_scores, axis=1)
#     test_scores_mean = np.mean(test_scores, axis=1)
#     test_scores_std = np.std(test_scores, axis=1)
#     plt.grid()
#
#     plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
#                      train_scores_mean + train_scores_std, alpha=0.1,
#                      color="r")
#     plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
#                      test_scores_mean + test_scores_std, alpha=0.1, color="g")
#     plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
#              label="Training score")
#     plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
#              label="Cross-validation score")
#
#     plt.legend(loc="best")
#     return plt

# %% [raw]
# title = "Learning Curves (Logistic Regression)"
# # Cross validation with 100 iterations to get smoother mean test and train
# # score curves, each time with 20% data randomly selected as a validation set.
# cv = ShuffleSplit(n_splits=100, test_size=0.2, random_state=42)
# estimator =log_reg
# plot_learning_curve(estimator,title,X_train_res,y_train_res,ylim=(0.87, 1.01), cv=cv, n_jobs=4)

# %% [raw]
# title = "Learning Curves (Decision Tree)"
# # Cross validation with 100 iterations to get smoother mean test and train
# # score curves, each time with 20% data randomly selected as a validation set.
# cv = ShuffleSplit(n_splits=100, test_size=0.2, random_state=42)
# estimator =tree_clf
#
# plot_learning_curve(estimator,title,X_train_res,y_train_res,ylim=(0.87, 1.01), cv=cv, n_jobs=4)

# %%
#Logistic regression with best estimator
from sklearn.linear_model import LogisticRegression

clf = LogisticRegression().fit(X_train_res,y_train_res)
y_pred = log_reg.predict(X_test)

# Model Evaluation metrics 
from sklearn.metrics import accuracy_score,recall_score,precision_score,f1_score
print('Accuracy Score : ' + str(accuracy_score(y_test,y_pred)))
print('Precision Score : ' + str(precision_score(y_test,y_pred)))
print('Recall Score : ' + str(recall_score(y_test,y_pred)))
print('F1 Score : ' + str(f1_score(y_test,y_pred)))

#Logistic Regression Classifier Confusion matrix
from sklearn.metrics import confusion_matrix
print('Confusion Matrix : \n' + str(confusion_matrix(y_test,y_pred)))
# Out:
# C:\Users\Aishwarya\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Accuracy Score : 0.7913111665086666
# Precision Score : 0.005867888677769085
# Recall Score : 0.7142857142857143
# F1 Score : 0.0116401529848678
# Confusion Matrix :
# [[67507 17789]
#  [   42   105]]

# %%
#Testing the logistic model with original data


y_pred = log_reg.predict(original_Xtest)

# Model Evaluation metrics 
from sklearn.metrics import accuracy_score,recall_score,precision_score,f1_score
print('Accuracy Score : ' + str(accuracy_score(original_ytest,y_pred)))
print('Precision Score : ' + str(precision_score(original_ytest,y_pred)))
print('Recall Score : ' + str(recall_score(original_ytest,y_pred)))
print('F1 Score : ' + str(f1_score(original_ytest,y_pred)))

#Logistic Regression Classifier Confusion matrix
from sklearn.metrics import confusion_matrix
print('Confusion Matrix : \n' + str(confusion_matrix(original_ytest,y_pred)))
# Out:
# Accuracy Score : 0.8589912396200909
# Precision Score : 0.006469270962926101
# Recall Score : 0.5306122448979592
# F1 Score : 0.0127826941986234
# Confusion Matrix :
# [[48877  7986]
#  [   46    52]]

# %%
# calculate AUC
plt.title('Receiver Operating Characteristic')
auc = roc_auc_score(original_ytest,y_pred)
print('AUC: %.3f' % auc)
# calculate roc curve
fpr, tpr, thresholds = roc_curve(original_ytest,y_pred)
# plot no skill
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
# show the plot
plt.show()
# Out:
# AUC: 0.695

# %%
#DT eith best estimator
y_pred_dec = tree_clf.predict(X_test)
print('Accuracy Score : ' + str(accuracy_score(y_test,y_pred_dec)))
print('Precision Score : ' + str(precision_score(y_test,y_pred_dec)))
print('Recall Score : ' + str(recall_score(y_test,y_pred_dec)))
print('F1 Score : ' + str(f1_score(y_test,y_pred_dec)))

#Classifier Confusion matrix
from sklearn.metrics import confusion_matrix
print('Confusion Matrix : \n' + str(confusion_matrix(y_test,y_pred_dec)))
# Out:
# Accuracy Score : 0.8789485387919431
# Precision Score : 0.010090332500480493
# Recall Score : 0.7142857142857143
# F1 Score : 0.019899554629015447
# Confusion Matrix :
# [[74995 10301]
#  [   42   105]]

# %%
y_pred_dec = tree_clf.predict(original_Xtest)

print('Accuracy Score : ' + str(accuracy_score(original_ytest,y_pred_dec)))
print('Precision Score : ' + str(precision_score(original_ytest,y_pred_dec)))
print('Recall Score : ' + str(recall_score(original_ytest,y_pred_dec)))
print('F1 Score : ' + str(f1_score(original_ytest,y_pred_dec)))

#Logistic Regression Classifier Confusion matrix
from sklearn.metrics import confusion_matrix
print('Confusion Matrix : \n' + str(confusion_matrix(original_ytest,y_pred_dec)))
# Out:
# Accuracy Score : 0.9048647320096206
# Precision Score : 0.009946583164487014
# Recall Score : 0.5510204081632653
# F1 Score : 0.019540437850551835
# Confusion Matrix :
# [[51488  5375]
#  [   44    54]]

# %%
# calculate AUC
plt.title('Receiver Operating Characteristic')
auc = roc_auc_score(original_ytest,y_pred)
print('AUC: %.3f' % auc)
# calculate roc curve
fpr, tpr, thresholds = roc_curve(original_ytest,y_pred)
# plot no skill
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
# show the plot
plt.show()
